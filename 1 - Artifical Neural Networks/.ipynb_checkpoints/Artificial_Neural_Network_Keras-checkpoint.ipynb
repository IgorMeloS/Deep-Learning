# %% [markdown]
# # Artificial Neural Network in Python with Keras
#
# This notebook is a simple demonstration to how to build an Artificial Neuron Network using TensorFlow to a classification problem.
#
# **Problem Description**
#
# The goal of program is to build a classification model to predict if a certain client will leave the bank service in the next six months.
#
# **Dataset Description**
#
# The dataset is composed by 10000 instances (rows) and 14 features (columns).   The features considered to build the model are:
#
# -  RowNumber (This is not important to the model)
# -  CustomerId (This is not important to the model)
# -  Surname (This is not important to the model)
# -  CreditScore (numerical variable)
# -  Geography (categorical variable)
# -  Gender (categorical variable)
# -  Age (numerical variable)
# -  Tenure (categorical variable)
# -  Balance (numerical variable)
# -  NumOfProducts (categorical variable)
# -  HasCrCard (categorical variable)
# -  EstimatedSalary (numerical variable)
# -  Exited (target)

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import keras # To build our ANN model
from keras.models import Sequential # To initialize the ANN
from keras.layers import Dense # To creat the hidden layers

# %% [markdown]
# ## Importing the Dataset

# %%
dataset = pd.read_csv('Churn_Modelling.csv')

# %% [markdown]
# ## Visualizing some informations from the dataset

# %%
dataset.shape

# %%
dataset.dtypes

# %%
dataset.isna().sum()

# %%
dataset.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
dataset.describe()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Visualizing the categorical variables

# %% [markdown]
# ### Target variable

# %%
dataset['Exited'].value_counts()

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.countplot(x=dataset['Exited'])
plt.subplot(1, 2, 2)
values = dataset.iloc[:, - 1].value_counts(normalize = True).values # to show the binirie values in parcentage
index = dataset.iloc[:, -1].value_counts(normalize = True).index
plt.pie(values, labels= index, autopct='%1.1f%%', colors=['b', 'tab:orange'])
plt.show()

# %% [markdown]
# ### Others categorical variables

# %%
categorical_list = ['Geography', 'Gender', 'Tenure', 'NumOfProducts', 'HasCrCard','IsActiveMember', 'Exited']

# %%
data_cat = dataset[categorical_list]

# %%
fig = plt.figure(figsize=(15, 15))
plt.suptitle('Pie Chart Distribution', fontsize = 20)
for i in range(1, data_cat.shape[1]):
    plt.subplot(2, 3, i)
    f = plt.gca()
    f.axes.get_yaxis().set_visible(False)
    f.set_title(data_cat.columns.values[i - 1])
  # Setting the biniries values
    values = data_cat.iloc[:, i - 1].value_counts(normalize = True).values # to show the binirie values in parcentage
    index = data_cat.iloc[:, i -1].value_counts(normalize = True).index
    plt.pie(values, labels= index, autopct='%1.1f%%')
    plt.axis('equal')
#fig.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
plt.figure(figsize=(15, 10))
for i in range(1, data_cat.shape[1]):
    plt.subplot(3, 3, i)
    sns.countplot(x=data_cat.iloc[: , i-1], hue=data_cat['Exited'])
plt.show()

# %% [markdown]
# ## Visualizing the numerical variables

# %%
numerical_list = ['CreditScore', 'Age', 'Balance', 'EstimatedSalary', 'Exited']

# %%
data_num  = dataset[numerical_list]

# %% [markdown]
# ### Distribution of numerical variables

# %%
plt.figure(figsize=(25,15))
plt.suptitle('Histograms of numerical variables (mean values)', fontsize = 20)
for i in range(1, data_num.shape[1]):
    plt.subplot(2, 2, i)
    f = plt.gca()
    sns.histplot(data_num.iloc[:, i-1], color = '#3F5D7D', kde= True)
plt.show()

# %%
plt.figure(figsize=(25,15))
plt.suptitle('Histograms of numerical variables (mean values)', fontsize = 20)
for i in range(1, data_num.shape[1]):
    plt.subplot(2, 2, i)
    f = plt.gca()
    sns.histplot(data=data_num, x=data_num.iloc[:, i-1], hue='Exited', kde = True)
plt.show()

# %% [markdown]
# ## Correlation and PairPlot (scatter)

# %% [markdown]
# ### Correlation with the response variable

# %%
column_drop = ['RowNumber', 'CustomerId', 'Surname', 'Exited']

# %%
dataset.drop(columns=column_drop).corrwith(dataset.Exited).plot.bar(
        figsize = (20, 10), title = "Correlation with Exited", fontsize = 15,
        rot = 45, grid = True)

# %% [markdown]
# ### Correlation Between the Variables

# %%
column_drop = ['RowNumber', 'CustomerId', 'Surname']
## Correlation Matrix
sns.set(style="white")

# Compute the correlation matrix
corr = dataset.drop(columns=column_drop).corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 20))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, vmin=-1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot = True)

# %% [markdown]
# ### Pair plot for the numerical variables

# %%
sns.pairplot(data_num, hue = 'Exited', kind = 'scatter', corner=True, diag_kind='None')

# %% [markdown]
# ## EDA conclusion
#
# **Target variable**
#
# Represented by 0 or 1 (stay/leave) shows a frequency of $79.6 \%$ for the customers which decided to stay in the bank against $20.4\%$ of customers that decided to leave the bank.
#
# **Categorical variables**
#
# The analysis of these variables shows that the most clients are French. The majority of clients are males. The frequency of these variables are approximately equals without a fact that requires attention and manipulation, it means feature engineering.
#
# **Numerical variables**
#
# The distribution of these variables are normal except for the salary. One interesting aspect is the age distribution for the clients which leaved the bank, the distribution shows that the almost clients have age among 40 and 50 years. This fact can be well visualized in the scatter plots.
#
# **Correlation**
#
# The correlation between the target and the independent variables are not so big, but considerable to build the model. The correlation among the independent variables are satisfactory, the almost of correlation show a low values.

# %% [markdown]
# # Building the Artificial Neuron Network

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Excluding not important columns

# %%
dataset = dataset.drop(columns=['RowNumber', 'CustomerId', 'Surname'])

# %% [markdown]
# ### Encoding Categorical Data

# %%
 dataset['Gender'] = dataset['Gender'].astype('category').cat.codes

# %% [markdown]
# #### One Hot Econding

# %%
dataset = pd.get_dummies(dataset)

# %%
dataset.head()

# %% [markdown]
# ### Defining the independent and target variable

# %%
response = dataset['Exited']

# %%
i_var = dataset.drop(columns=['Exited'])

# %% [markdown]
# ### Splitting the Dataset into train and test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(i_var, response, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Feature Scaling
# In almost ANN models we must to apply feature scale.

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train_bckp = pd.DataFrame(sc_X.fit_transform(X_train))
X_test_bckp = pd.DataFrame(sc_X.transform(X_test))
X_train_bckp.columns = X_train.columns.values
X_test_bckp.columns = X_test.columns.values
X_train_bckp.index = X_train.index.values
X_test_bckp.index = X_test.index.values
X_train = X_train_bckp
X_test = X_test_bckp

# %% [markdown]
# ## The Artificial Neuron Network - ANN
#
# An Artificial Neuron Network is a technique that tries to reproduce brain functions.  To build an ANN, we consider a set of input information about something, each of these information will be considered as a neuron, we call this set of neuron input layer. As we know, in the brain we have many neurons and the communication among them is made by synapses process. The neurons from the input layer will communicate with other set of neurons in a hidden layer by the synapses process. Once the communication between the neurons of input and hidden layer is made, the initial information is changed, in this moment, the neurons of the hidden layer will communicate with a others neurons, these neurons is considered as a output layer and it gives a response about something. For example, in a classification model, if we consider five independent variables, the input layer will be composed by five neurons, these neurons communicate with the hidden layer (the number of neurons must be chosen), the hidden layer communicate with the output layer, that provides the final response 0 or 1, if we have two class.
#
# **How do synapses work in an ANN?**
#
# The synapses process in an ANN is made by an activation function, this function transforms the input information according with an associated weight (this might be interpreted as an importance degree to each input variable). We have some kind of activation function as
# - Threshold function
# - Sigmoid function
# - Rectifier function
# - Hyperbolic tangent function.
# For this notebook we are interested in the rectifier function and sigmoid function.
#
# The rectifier function is defined as $\phi(x) = \max(x,0)$, if a certain values is less than 0 the function returns 0, otherwise the function returns the maximum value. The synapses or the communication is made according $\sum_{i=1}^{m}w_{i}x_{i}$, where $m$ is the number of input variable. We consider the rectifier function between the input layer and the hidden layers. The activation function that we consider to make the communication among the hidden and output layer is the sigmoid function. The sigmoid function returns the probability of occurrence to certain class, this function is defined as $\phi(x) = \frac{1}{1 + e^{-x}}$.
#
# **How do an ANN learn?**
#
# The learning process of an ANN starts with the input parameters in a input layer, this layer communicate with the hidden layer by synapses. The next step is the communication among the hidden layer with the output layer, to obtain a response. In this stage, the learning process is not ended. After the response, the ANN must calculate the loss function to measure the precision of the prediction. Once the loss function was calculated there is the retro-propagation process, this process tries to find the minimal of the loss function changing the associated weights to each neuron. After this step, the ANN remake the previous process of synapses among the layers. The number of retro-propagation is defined as epochs.
#
# **About loss function**
#
# One of the most used loss function is the cross entropy. To more details [see](https://towardsdatascience.com/cross-entropy-loss-function-f38c4ec8643e).
#
# **About the retro-propagation**
#
# Here, we consider the stochastic gradient descent. This method tries to minimize the loss function changing the weights of each neuron. In this process, if we have 128 instances, we choose a batch number as 32, it means that we calculate the response for the associated batch number and we returns to the begin to remake the same process to other 32 instances. To more details [see](https://en.wikipedia.org/wiki/Stochastic_gradient_descent#Adam).
#
# **Summarizing the ANN process**
#
#  1. Initializing the ANN
#  2. Build the input layer
#  3. Build the hidden layers
#  4. Build the output layer
#  5. Training the ANN
#
#    1. Compile
#    2. Train.

# %% [markdown]
# ## Initializing the ANN
#
# The first step is to create an object to build a sequence layer. This sequence layer takes account the input layer (the parameters that we initialize the ANN), the hidden layers and output layer. To do it, we utilize the Keras library and the object Sequencial.

# %%
classifier = Sequential() # To initiate the ANN

# %% [markdown]
# ## Input layer
#
# In this step, we create the input layer, it means, we set all independent variables (considering that these variables as input neurons). To communicate the input layer with the first hidden layer, we must to choose an activation function. For this case, we choose rectifier function (the weights to each input parameters are chosen randomly by the ann object). Units is the number of input neurons, relu is the activation function.

# %%
classifier.add(Dense(units=X_train.shape[1], activation='relu',
                    kernel_initializer= 'uniform',
                    input_dim=X_train.shape[1])) # Creating the hidden layer

# %% [markdown]
# ## Hidden layers
#
# Here, we set the hidden layers. We can put how much we want. For this problem, we consider just one hidden layer. The object to create the hidden layer is the same to the input layer, but we can change it according with the problem. The parameters are the same of the input layer.

# %%
layers.Dropout(0.2) # To drop 20% of input neurons, to avoid overfit.
classifier.add(Dense(units=X_train.shape[1], activation='relu',
                    kernel_initializer= 'uniform')) # Creating the hidden layer

# %% [markdown]
# ## Output layer
#
# The last layer is the output layer. We use the same object the we used to build the preceding layers, but here, we make some changes in the parameters. Like this problem has a binary response yes or no, the number of neuron corresponds to 1, but if the response gives more then two results (0, 1, 2, for example), we must to consider the correspondent number of responses. The second change is on the activation function. Here, we consider sigmoid activation function, for one simple reason, this gives to us the probability which will be interpreted as 0 or 1 according with the values. Likelihood less than $0.5$ is considered as 0, otherwise 1.

# %%
layers.Dropout(0.2) 
classifier.add(Dense(units=1, activation='sigmoid',
                    kernel_initializer= 'uniform')) # Creating the hidden layer

# %% [markdown]
# ## Learning process of the ANN

# %% [markdown]
# ### Compiling the ANN
#
# Compile the ANN is one of most important step. We select a method to optimize our ANN, stochastic gradient descent, represented by adam. The lost function is also very import, because from this function we are able to improve the accuracy, precision and other relevant parameters. The lost function that we are going to use is Binary Cross Entropy (due to have a binary response). Finally, the metric which we choose is the accuracy. Beyond this metric, we have others important metrics as F1, precision and recall.

# %%
classifier.compile(optimizer='adam', loss='binary_crossentropy', 
                   metrics=['accuracy', metrics.Recall(), metrics.Precision()])

# %% [markdown]
# ### Training the ANN
#
# Now we train the ANN. Here we have two important hype parameters. Batch size determines how many instances the stochastic gradient descent will consider to work in the minimizing process. Epochs indicates the number of retro-propagation we want to train the model.

# %%
classifier.fit(X_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 0s 660us/step - loss: 0.5654 - accuracy: 0.7958
# Epoch 2/100
# 250/250 [==============================] - 0s 636us/step - loss: 0.4385 - accuracy: 0.7960
# Epoch 3/100
# 250/250 [==============================] - 0s 664us/step - loss: 0.4317 - accuracy: 0.7960
# Epoch 4/100
# 250/250 [==============================] - 0s 655us/step - loss: 0.4286 - accuracy: 0.7960
# Epoch 5/100
# 250/250 [==============================] - 0s 610us/step - loss: 0.4261 - accuracy: 0.7960
# Epoch 6/100
# 250/250 [==============================] - 0s 646us/step - loss: 0.4236 - accuracy: 0.7960
# Epoch 7/100
# 250/250 [==============================] - 0s 632us/step - loss: 0.4211 - accuracy: 0.8016
# Epoch 8/100
# 250/250 [==============================] - 0s 622us/step - loss: 0.4192 - accuracy: 0.8175
# Epoch 9/100
# 250/250 [==============================] - 0s 632us/step - loss: 0.4176 - accuracy: 0.8206
# Epoch 10/100
# 250/250 [==============================] - 0s 647us/step - loss: 0.4161 - accuracy: 0.8267
# Epoch 11/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4151 - accuracy: 0.8270
# Epoch 12/100
# 250/250 [==============================] - 0s 696us/step - loss: 0.4142 - accuracy: 0.8288
# Epoch 13/100
# 250/250 [==============================] - 0s 724us/step - loss: 0.4131 - accuracy: 0.8307
# Epoch 14/100
# 250/250 [==============================] - 0s 646us/step - loss: 0.4126 - accuracy: 0.8304
# Epoch 15/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4114 - accuracy: 0.8335
# Epoch 16/100
# 250/250 [==============================] - 0s 715us/step - loss: 0.4109 - accuracy: 0.8321
# Epoch 17/100
# 250/250 [==============================] - 0s 716us/step - loss: 0.4100 - accuracy: 0.8336
# Epoch 18/100
# 250/250 [==============================] - 0s 709us/step - loss: 0.4094 - accuracy: 0.8338
# Epoch 19/100
# 250/250 [==============================] - 0s 672us/step - loss: 0.4087 - accuracy: 0.8341
# Epoch 20/100
# 250/250 [==============================] - 0s 646us/step - loss: 0.4082 - accuracy: 0.8335
# Epoch 21/100
# 250/250 [==============================] - 0s 650us/step - loss: 0.4075 - accuracy: 0.8334
# Epoch 22/100
# 250/250 [==============================] - 0s 748us/step - loss: 0.4069 - accuracy: 0.8349
# Epoch 23/100
# 250/250 [==============================] - 0s 751us/step - loss: 0.4061 - accuracy: 0.8347
# Epoch 24/100
# 250/250 [==============================] - 0s 714us/step - loss: 0.4057 - accuracy: 0.8342
# Epoch 25/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4055 - accuracy: 0.8349
# Epoch 26/100
# 250/250 [==============================] - 0s 694us/step - loss: 0.4050 - accuracy: 0.8336
# Epoch 27/100
# 250/250 [==============================] - 0s 623us/step - loss: 0.4046 - accuracy: 0.8346
# Epoch 28/100
# 250/250 [==============================] - 0s 677us/step - loss: 0.4042 - accuracy: 0.8357
# Epoch 29/100
# 250/250 [==============================] - 0s 657us/step - loss: 0.4040 - accuracy: 0.8347
# Epoch 30/100
# 250/250 [==============================] - 0s 667us/step - loss: 0.4039 - accuracy: 0.8351
# Epoch 31/100
# 250/250 [==============================] - 0s 662us/step - loss: 0.4035 - accuracy: 0.8364
# Epoch 32/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4037 - accuracy: 0.8354
# Epoch 33/100
# 250/250 [==============================] - 0s 665us/step - loss: 0.4032 - accuracy: 0.8366
# Epoch 34/100
# 250/250 [==============================] - 0s 611us/step - loss: 0.4025 - accuracy: 0.8354
# Epoch 35/100
# 250/250 [==============================] - 0s 668us/step - loss: 0.4029 - accuracy: 0.8363
# Epoch 36/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.4026 - accuracy: 0.8357
# Epoch 37/100
# 250/250 [==============================] - 0s 644us/step - loss: 0.4022 - accuracy: 0.8366
# Epoch 38/100
# 250/250 [==============================] - 0s 661us/step - loss: 0.4022 - accuracy: 0.8359
# Epoch 39/100
# 250/250 [==============================] - 0s 651us/step - loss: 0.4020 - accuracy: 0.8357
# Epoch 40/100
# 250/250 [==============================] - 0s 653us/step - loss: 0.4020 - accuracy: 0.8365
# Epoch 41/100
# 250/250 [==============================] - 0s 674us/step - loss: 0.4019 - accuracy: 0.8366
# Epoch 42/100
# 250/250 [==============================] - 0s 679us/step - loss: 0.4023 - accuracy: 0.8344
# Epoch 43/100
# 250/250 [==============================] - 0s 825us/step - loss: 0.4015 - accuracy: 0.8359
# Epoch 44/100
# 250/250 [==============================] - 0s 756us/step - loss: 0.4016 - accuracy: 0.8360
# Epoch 45/100
# 250/250 [==============================] - 0s 784us/step - loss: 0.4014 - accuracy: 0.8356
# Epoch 46/100
# 250/250 [==============================] - 0s 735us/step - loss: 0.4012 - accuracy: 0.8356
# Epoch 47/100
# 250/250 [==============================] - 0s 679us/step - loss: 0.4014 - accuracy: 0.8364
# Epoch 48/100
# 250/250 [==============================] - 0s 833us/step - loss: 0.4010 - accuracy: 0.8357
# Epoch 49/100
# 250/250 [==============================] - 0s 698us/step - loss: 0.4012 - accuracy: 0.8361
# Epoch 50/100
# 250/250 [==============================] - 0s 688us/step - loss: 0.4013 - accuracy: 0.8364
# Epoch 51/100
# 250/250 [==============================] - 0s 707us/step - loss: 0.4009 - accuracy: 0.8376
# Epoch 52/100
# 250/250 [==============================] - 0s 760us/step - loss: 0.4007 - accuracy: 0.8363
# Epoch 53/100
# 250/250 [==============================] - 0s 665us/step - loss: 0.4005 - accuracy: 0.8379
# Epoch 54/100
# 250/250 [==============================] - 0s 684us/step - loss: 0.4010 - accuracy: 0.8365
# Epoch 55/100
# 250/250 [==============================] - 0s 714us/step - loss: 0.4004 - accuracy: 0.8372
# Epoch 56/100
# 250/250 [==============================] - 0s 851us/step - loss: 0.4003 - accuracy: 0.8372
# Epoch 57/100
# 250/250 [==============================] - 0s 691us/step - loss: 0.4004 - accuracy: 0.8370
# Epoch 58/100
# 250/250 [==============================] - 0s 640us/step - loss: 0.4001 - accuracy: 0.8367
# Epoch 59/100
# 250/250 [==============================] - 0s 658us/step - loss: 0.4001 - accuracy: 0.8367
# Epoch 60/100
# 250/250 [==============================] - 0s 679us/step - loss: 0.4003 - accuracy: 0.8360
# Epoch 61/100
# 250/250 [==============================] - 0s 738us/step - loss: 0.3999 - accuracy: 0.8374
# Epoch 62/100
# 250/250 [==============================] - 0s 726us/step - loss: 0.3997 - accuracy: 0.8376
# Epoch 63/100
# 250/250 [==============================] - 0s 720us/step - loss: 0.4005 - accuracy: 0.8374
# Epoch 64/100
# 250/250 [==============================] - 0s 691us/step - loss: 0.3999 - accuracy: 0.8372
# Epoch 65/100
# 250/250 [==============================] - 0s 687us/step - loss: 0.3997 - accuracy: 0.8360
# Epoch 66/100
# 250/250 [==============================] - 0s 623us/step - loss: 0.4001 - accuracy: 0.8366
# Epoch 67/100
# 250/250 [==============================] - 0s 626us/step - loss: 0.3997 - accuracy: 0.8360
# Epoch 68/100
# 250/250 [==============================] - 0s 619us/step - loss: 0.3996 - accuracy: 0.8369
# Epoch 69/100
# 250/250 [==============================] - 0s 622us/step - loss: 0.3997 - accuracy: 0.8365
# Epoch 70/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3995 - accuracy: 0.8379
# Epoch 71/100
# 250/250 [==============================] - 0s 630us/step - loss: 0.3994 - accuracy: 0.8365
# Epoch 72/100
# 250/250 [==============================] - 0s 612us/step - loss: 0.3998 - accuracy: 0.8381
# Epoch 73/100
# 250/250 [==============================] - 0s 639us/step - loss: 0.3997 - accuracy: 0.8372
# Epoch 74/100
# 250/250 [==============================] - 0s 651us/step - loss: 0.3996 - accuracy: 0.8366
# Epoch 75/100
# 250/250 [==============================] - 0s 643us/step - loss: 0.3993 - accuracy: 0.8376
# Epoch 76/100
# 250/250 [==============================] - 0s 637us/step - loss: 0.3994 - accuracy: 0.8360
# Epoch 77/100
# 250/250 [==============================] - 0s 633us/step - loss: 0.3994 - accuracy: 0.8365
# Epoch 78/100
# 250/250 [==============================] - 0s 615us/step - loss: 0.3991 - accuracy: 0.8378
# Epoch 79/100
# 250/250 [==============================] - 0s 651us/step - loss: 0.3994 - accuracy: 0.8367
# Epoch 80/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3993 - accuracy: 0.8372
# Epoch 81/100
# 250/250 [==============================] - 0s 679us/step - loss: 0.3992 - accuracy: 0.8371
# Epoch 82/100
# 250/250 [==============================] - 0s 664us/step - loss: 0.3992 - accuracy: 0.8359
# Epoch 83/100
# 250/250 [==============================] - 0s 694us/step - loss: 0.3996 - accuracy: 0.8376
# Epoch 84/100
# 250/250 [==============================] - 0s 691us/step - loss: 0.3992 - accuracy: 0.8376
# Epoch 85/100
# 250/250 [==============================] - 0s 643us/step - loss: 0.3991 - accuracy: 0.8369
# Epoch 86/100
# 250/250 [==============================] - 0s 613us/step - loss: 0.3990 - accuracy: 0.8376
# Epoch 87/100
# 250/250 [==============================] - 0s 708us/step - loss: 0.3992 - accuracy: 0.8366
# Epoch 88/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3989 - accuracy: 0.8380
# Epoch 89/100
# 250/250 [==============================] - 0s 615us/step - loss: 0.3989 - accuracy: 0.8379
# Epoch 90/100
# 250/250 [==============================] - 0s 653us/step - loss: 0.3991 - accuracy: 0.8375
# Epoch 91/100
# 250/250 [==============================] - 0s 703us/step - loss: 0.3993 - accuracy: 0.8375
# Epoch 92/100
# 250/250 [==============================] - 0s 697us/step - loss: 0.3992 - accuracy: 0.8369
# Epoch 93/100
# 250/250 [==============================] - 0s 614us/step - loss: 0.3989 - accuracy: 0.8361
# Epoch 94/100
# 250/250 [==============================] - 0s 658us/step - loss: 0.3991 - accuracy: 0.8363
# Epoch 95/100
# 250/250 [==============================] - 0s 710us/step - loss: 0.3989 - accuracy: 0.8375
# Epoch 96/100
# 250/250 [==============================] - 0s 652us/step - loss: 0.3987 - accuracy: 0.8366
# Epoch 97/100
# 250/250 [==============================] - 0s 610us/step - loss: 0.3989 - accuracy: 0.8372
# Epoch 98/100
# 250/250 [==============================] - 0s 626us/step - loss: 0.3992 - accuracy: 0.8379
# Epoch 99/100
# 250/250 [==============================] - 0s 618us/step - loss: 0.3990 - accuracy: 0.8363
# Epoch 100/100
# 250/250 [==============================] - 0s 1ms/step - loss: 0.3989 - accuracy: 0.8370

# %% [markdown]
# ## Making a single prediction
#
# Here, we make a simple prediction. Remember, Geography and Gender was changed. We must take it account.

# %%
print(classifier.predict(sc_X.transform([[1, 0, 0, 600, 1, 1, 40, 60000, 2, 1, 1, 50000]])) > 0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a316c92f8b4f> in <module>()
# ----> 1 print(classifier.predict(sc_X.transform([[1, 0, 0, 600, 1, 1, 40, 60000, 2, 1, 1, 50000]])) > 0.5)
#
# NameError: name 'classifier' is not defined

# %% [markdown]
# ## Predicting the test results

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5) # Here we must put it, because we have as outcome the probability, but we want a binary response.

# %% [markdown]
# ## Making the confusion matrix and metrics scores

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure()
sns.heatmap(cm, annot=True)
plt.show()
# Out:
# [[1539   56]
#  [ 255  150]]
# 0.8445

# %%
# Here, we consider the metrics class from TensorFlow library.
m1 = metrics.Accuracy() # Object
m2 = metrics.Recall()
m3 = metrics.Precision()

m1.update_state(y_test, y_pred) # Calculating the metric
m2.update_state(y_test, y_pred)
m3.update_state(y_test, y_pred)

print('Metric results for the test set\n')

print('Accuracy {:.2f}%'.format(m1.result().numpy()*100))
print('Recall {:.2f}%'.format(m2.result().numpy()*100))
print('Precision {:.2f}%'.format(m3.result().numpy()*100))

# %%
score_train = classifier.evaluate(X_train, y_train)
print('\n')
print('Metric results for the training set\n')

print('Accuracy {:.2f}%'.format(score_train[1]*100))
print('Recall {:.2f}%'.format(score_train[2]*100))
print('Precision {:.2f}%'.format(score_train[3]*100))

# %% [markdown]
# ## Metrics with cross validate

# %%
def build_classifier(optimizer='adam'):
    classifier = Sequential()
    classifier.add(Dense(units = X.shape[1], kernel_initializer = 'uniform', activation = 'relu', input_dim = X.shape[1]))
    classifier.add(Dense(units = X.shape[1], kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = X.shape[1], kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

# %%
scoring = ['accuracy', 'recall', 'precision'] # List of metrics

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_validate
classifier = KerasClassifier(build_fn = build_classifier, batch_size = 32, epochs = 100)
accuracies = cross_validate(estimator = classifier, X = X_train, y = y_train, 
                             cv = 10, n_jobs = -1, scoring = scoring)

# %%
print('Metric results with cross validate cv=10')
print('\n')
print("Accuracy: {:.2f} %".format(accuracies['test_accuracy'].mean()*100))
print("Recall: {:.2f} %".format(accuracies['test_recall'].mean()*100))
print("Precision: {:.2f} %".format(accuracies['test_precision'].mean()*100))

# %% [markdown]
# ## Boosting the model with GridSearchCV

# %%
scoring = {'ACC' : 'accuracy', 'REC' : 'recall', 'PC' : 'precision'} # Dictionary of metrics
from sklearn.model_selection import GridSearchCV

classifier = KerasClassifier(build_fn = build_classifier)

parameters = {'batch_size': [8, 16, 32],
              'epochs': [50, 100, 500],
              'optimizer': ['adam', 'rmsprop']}

grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = scoring,
                           refit = 'ACC',
                           cv = 10, n_jobs = -1)
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 1s 644us/step - loss: 0.4750 - accuracy: 0.7956
# Epoch 2/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.4295 - accuracy: 0.7960
# Epoch 3/500
# 1000/1000 [==============================] - 1s 676us/step - loss: 0.4245 - accuracy: 0.7970
# Epoch 4/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.4192 - accuracy: 0.8213
# Epoch 5/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.4164 - accuracy: 0.8253
# Epoch 6/500
# 1000/1000 [==============================] - 1s 643us/step - loss: 0.4137 - accuracy: 0.8271
# Epoch 7/500
# 1000/1000 [==============================] - 1s 572us/step - loss: 0.4128 - accuracy: 0.8304
# Epoch 8/500
# 1000/1000 [==============================] - 1s 651us/step - loss: 0.4111 - accuracy: 0.8313
# Epoch 9/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.4102 - accuracy: 0.8324
# Epoch 10/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.4088 - accuracy: 0.8324
# Epoch 11/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.4082 - accuracy: 0.8347
# Epoch 12/500
# 1000/1000 [==============================] - 1s 687us/step - loss: 0.4070 - accuracy: 0.8338
# Epoch 13/500
# 1000/1000 [==============================] - 1s 529us/step - loss: 0.4062 - accuracy: 0.8332
# Epoch 14/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.4056 - accuracy: 0.8357
# Epoch 15/500
# 1000/1000 [==============================] - 1s 708us/step - loss: 0.4059 - accuracy: 0.8365
# Epoch 16/500
# 1000/1000 [==============================] - 1s 676us/step - loss: 0.4050 - accuracy: 0.8356
# Epoch 17/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.4048 - accuracy: 0.8345
# Epoch 18/500
# 1000/1000 [==============================] - 1s 705us/step - loss: 0.4044 - accuracy: 0.8345
# Epoch 19/500
# 1000/1000 [==============================] - 1s 666us/step - loss: 0.4044 - accuracy: 0.8341
# Epoch 20/500
# 1000/1000 [==============================] - 1s 662us/step - loss: 0.4032 - accuracy: 0.8364
# Epoch 21/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.4038 - accuracy: 0.8361
# Epoch 22/500
# 1000/1000 [==============================] - 1s 686us/step - loss: 0.4032 - accuracy: 0.8346
# Epoch 23/500
# 1000/1000 [==============================] - 1s 686us/step - loss: 0.4034 - accuracy: 0.8356
# Epoch 24/500
# 1000/1000 [==============================] - 1s 705us/step - loss: 0.4032 - accuracy: 0.8341
# Epoch 25/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.4026 - accuracy: 0.8355
# Epoch 26/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.4028 - accuracy: 0.8326
# Epoch 27/500
# 1000/1000 [==============================] - 1s 676us/step - loss: 0.4027 - accuracy: 0.8353
# Epoch 28/500
# 1000/1000 [==============================] - 1s 649us/step - loss: 0.4022 - accuracy: 0.8347
# Epoch 29/500
# 1000/1000 [==============================] - 1s 683us/step - loss: 0.4022 - accuracy: 0.8344
# Epoch 30/500
# 1000/1000 [==============================] - 1s 668us/step - loss: 0.4021 - accuracy: 0.8364
# Epoch 31/500
# 1000/1000 [==============================] - 1s 537us/step - loss: 0.4018 - accuracy: 0.8367
# Epoch 32/500
# 1000/1000 [==============================] - 1s 609us/step - loss: 0.4015 - accuracy: 0.8324
# Epoch 33/500
# 1000/1000 [==============================] - 1s 662us/step - loss: 0.4015 - accuracy: 0.8346
# Epoch 34/500
# 1000/1000 [==============================] - 1s 676us/step - loss: 0.4019 - accuracy: 0.8354
# Epoch 35/500
# 1000/1000 [==============================] - 1s 664us/step - loss: 0.4017 - accuracy: 0.8344
# Epoch 36/500
# 1000/1000 [==============================] - 1s 694us/step - loss: 0.4015 - accuracy: 0.8359
# Epoch 37/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.4013 - accuracy: 0.8359
# Epoch 38/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.4011 - accuracy: 0.8351
# Epoch 39/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.4014 - accuracy: 0.8351
# Epoch 40/500
# 1000/1000 [==============================] - 1s 704us/step - loss: 0.4013 - accuracy: 0.8344
# Epoch 41/500
# 1000/1000 [==============================] - 1s 697us/step - loss: 0.4010 - accuracy: 0.8357
# Epoch 42/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.4017 - accuracy: 0.8359
# Epoch 43/500
# 1000/1000 [==============================] - 1s 693us/step - loss: 0.4014 - accuracy: 0.8346
# Epoch 44/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.4005 - accuracy: 0.8363
# Epoch 45/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.4010 - accuracy: 0.8354
# Epoch 46/500
# 1000/1000 [==============================] - 1s 669us/step - loss: 0.4007 - accuracy: 0.8378
# Epoch 47/500
# 1000/1000 [==============================] - 1s 650us/step - loss: 0.4008 - accuracy: 0.8351
# Epoch 48/500
# 1000/1000 [==============================] - 1s 609us/step - loss: 0.4009 - accuracy: 0.8346
# Epoch 49/500
# 1000/1000 [==============================] - 1s 645us/step - loss: 0.4000 - accuracy: 0.8364
# Epoch 50/500
# 1000/1000 [==============================] - 1s 653us/step - loss: 0.4005 - accuracy: 0.8356
# Epoch 51/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.4008 - accuracy: 0.8349
# Epoch 52/500
# 1000/1000 [==============================] - 1s 651us/step - loss: 0.4006 - accuracy: 0.8375
# Epoch 53/500
# 1000/1000 [==============================] - 1s 728us/step - loss: 0.4000 - accuracy: 0.83630s - loss: 0.4140
# Epoch 54/500
# 1000/1000 [==============================] - 1s 657us/step - loss: 0.4004 - accuracy: 0.8350
# Epoch 55/500
# 1000/1000 [==============================] - 1s 652us/step - loss: 0.4001 - accuracy: 0.8365
# Epoch 56/500
# 1000/1000 [==============================] - 1s 661us/step - loss: 0.4001 - accuracy: 0.8360
# Epoch 57/500
# 1000/1000 [==============================] - 1s 647us/step - loss: 0.4004 - accuracy: 0.8350
# Epoch 58/500
# 1000/1000 [==============================] - 1s 633us/step - loss: 0.4002 - accuracy: 0.8363
# Epoch 59/500
# 1000/1000 [==============================] - 1s 662us/step - loss: 0.3999 - accuracy: 0.8361
# Epoch 60/500
# 1000/1000 [==============================] - 1s 649us/step - loss: 0.4003 - accuracy: 0.8346
# Epoch 61/500
# 1000/1000 [==============================] - 1s 669us/step - loss: 0.3997 - accuracy: 0.8354
# Epoch 62/500
# 1000/1000 [==============================] - 1s 639us/step - loss: 0.4009 - accuracy: 0.8354
# Epoch 63/500
# 1000/1000 [==============================] - 1s 630us/step - loss: 0.4000 - accuracy: 0.8367
# Epoch 64/500
# 1000/1000 [==============================] - 1s 631us/step - loss: 0.3995 - accuracy: 0.8349
# Epoch 65/500
# 1000/1000 [==============================] - 1s 630us/step - loss: 0.3996 - accuracy: 0.8367
# Epoch 66/500
# 1000/1000 [==============================] - 1s 638us/step - loss: 0.3998 - accuracy: 0.8336
# Epoch 67/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3999 - accuracy: 0.8361
# Epoch 68/500
# 1000/1000 [==============================] - 1s 617us/step - loss: 0.3996 - accuracy: 0.8360
# Epoch 69/500
# 1000/1000 [==============================] - 1s 622us/step - loss: 0.3997 - accuracy: 0.8347
# Epoch 70/500
# 1000/1000 [==============================] - 1s 616us/step - loss: 0.3991 - accuracy: 0.8364
# Epoch 71/500
# 1000/1000 [==============================] - 1s 632us/step - loss: 0.4000 - accuracy: 0.8356
# Epoch 72/500
# 1000/1000 [==============================] - 1s 623us/step - loss: 0.3999 - accuracy: 0.8363
# Epoch 73/500
# 1000/1000 [==============================] - 1s 617us/step - loss: 0.3998 - accuracy: 0.8354
# Epoch 74/500
# 1000/1000 [==============================] - 1s 637us/step - loss: 0.3995 - accuracy: 0.83470s - loss: 0.3977 - accu
# Epoch 75/500
# 1000/1000 [==============================] - 1s 635us/step - loss: 0.3995 - accuracy: 0.8355
# Epoch 76/500
# 1000/1000 [==============================] - 1s 618us/step - loss: 0.3996 - accuracy: 0.8349
# Epoch 77/500
# 1000/1000 [==============================] - 1s 625us/step - loss: 0.3998 - accuracy: 0.8360
# Epoch 78/500
# 1000/1000 [==============================] - 1s 646us/step - loss: 0.3994 - accuracy: 0.8366
# Epoch 79/500
# 1000/1000 [==============================] - 1s 659us/step - loss: 0.3998 - accuracy: 0.8353
# Epoch 80/500
# 1000/1000 [==============================] - 1s 666us/step - loss: 0.3996 - accuracy: 0.83510s - loss: 0.3872 - ac
# Epoch 81/500
# 1000/1000 [==============================] - 1s 648us/step - loss: 0.3997 - accuracy: 0.8359
# Epoch 82/500
# 1000/1000 [==============================] - 1s 649us/step - loss: 0.3991 - accuracy: 0.8366
# Epoch 83/500
# 1000/1000 [==============================] - 1s 658us/step - loss: 0.4002 - accuracy: 0.8366
# Epoch 84/500
# 1000/1000 [==============================] - 1s 659us/step - loss: 0.3997 - accuracy: 0.8353
# Epoch 85/500
# 1000/1000 [==============================] - 1s 663us/step - loss: 0.3999 - accuracy: 0.8359
# Epoch 86/500
# 1000/1000 [==============================] - 1s 671us/step - loss: 0.3995 - accuracy: 0.8345
# Epoch 87/500
# 1000/1000 [==============================] - 1s 646us/step - loss: 0.3994 - accuracy: 0.8360
# Epoch 88/500
# 1000/1000 [==============================] - 1s 659us/step - loss: 0.4000 - accuracy: 0.8357
# Epoch 89/500
# 1000/1000 [==============================] - 1s 656us/step - loss: 0.4000 - accuracy: 0.8345
# Epoch 90/500
# 1000/1000 [==============================] - 1s 649us/step - loss: 0.3996 - accuracy: 0.8353
# Epoch 91/500
# 1000/1000 [==============================] - 1s 645us/step - loss: 0.3998 - accuracy: 0.8363
# Epoch 92/500
# 1000/1000 [==============================] - 1s 663us/step - loss: 0.3996 - accuracy: 0.8371
# Epoch 93/500
# 1000/1000 [==============================] - 1s 652us/step - loss: 0.3997 - accuracy: 0.8365
# Epoch 94/500
# 1000/1000 [==============================] - 1s 649us/step - loss: 0.3999 - accuracy: 0.8356
# Epoch 95/500
# 1000/1000 [==============================] - 1s 650us/step - loss: 0.3988 - accuracy: 0.8350
# Epoch 96/500
# 1000/1000 [==============================] - 1s 599us/step - loss: 0.3996 - accuracy: 0.8367
# Epoch 97/500
# 1000/1000 [==============================] - 1s 645us/step - loss: 0.3995 - accuracy: 0.8359
# Epoch 98/500
# 1000/1000 [==============================] - 1s 636us/step - loss: 0.3995 - accuracy: 0.8364
# Epoch 99/500
# 1000/1000 [==============================] - 1s 651us/step - loss: 0.3994 - accuracy: 0.8374
# Epoch 100/500
# 1000/1000 [==============================] - 1s 664us/step - loss: 0.3995 - accuracy: 0.8363
# Epoch 101/500
# 1000/1000 [==============================] - 1s 653us/step - loss: 0.3992 - accuracy: 0.8353
# Epoch 102/500
# 1000/1000 [==============================] - 1s 589us/step - loss: 0.3993 - accuracy: 0.8371
# Epoch 103/500
# 1000/1000 [==============================] - 1s 704us/step - loss: 0.3993 - accuracy: 0.8346
# Epoch 104/500
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.3993 - accuracy: 0.8360
# Epoch 105/500
# 1000/1000 [==============================] - 1s 647us/step - loss: 0.3988 - accuracy: 0.8351
# Epoch 106/500
# 1000/1000 [==============================] - 1s 634us/step - loss: 0.3992 - accuracy: 0.8386
# Epoch 107/500
# 1000/1000 [==============================] - 1s 669us/step - loss: 0.3995 - accuracy: 0.8356
# Epoch 108/500
# 1000/1000 [==============================] - 1s 644us/step - loss: 0.3995 - accuracy: 0.8359
# Epoch 109/500
# 1000/1000 [==============================] - 1s 663us/step - loss: 0.3994 - accuracy: 0.8351
# Epoch 110/500
# 1000/1000 [==============================] - 1s 645us/step - loss: 0.3993 - accuracy: 0.8364
# Epoch 111/500
# 1000/1000 [==============================] - 1s 651us/step - loss: 0.3989 - accuracy: 0.8370
# Epoch 112/500
# 1000/1000 [==============================] - 1s 647us/step - loss: 0.3993 - accuracy: 0.8360
# Epoch 113/500
# 1000/1000 [==============================] - 1s 653us/step - loss: 0.3999 - accuracy: 0.8355
# Epoch 114/500
# 1000/1000 [==============================] - 1s 636us/step - loss: 0.3992 - accuracy: 0.8347
# Epoch 115/500
# 1000/1000 [==============================] - 1s 608us/step - loss: 0.3993 - accuracy: 0.8356
# Epoch 116/500
# 1000/1000 [==============================] - 1s 631us/step - loss: 0.3995 - accuracy: 0.8356
# Epoch 117/500
# 1000/1000 [==============================] - 1s 643us/step - loss: 0.3995 - accuracy: 0.8355
# Epoch 118/500
# 1000/1000 [==============================] - 1s 640us/step - loss: 0.3990 - accuracy: 0.8364
# Epoch 119/500
# 1000/1000 [==============================] - 1s 656us/step - loss: 0.3993 - accuracy: 0.8371
# Epoch 120/500
# 1000/1000 [==============================] - 1s 647us/step - loss: 0.3995 - accuracy: 0.8364
# Epoch 121/500
# 1000/1000 [==============================] - 1s 660us/step - loss: 0.3992 - accuracy: 0.8365
# Epoch 122/500
# 1000/1000 [==============================] - 1s 648us/step - loss: 0.3995 - accuracy: 0.8349
# Epoch 123/500
# 1000/1000 [==============================] - 1s 668us/step - loss: 0.3990 - accuracy: 0.8356
# Epoch 124/500
# 1000/1000 [==============================] - 1s 665us/step - loss: 0.3993 - accuracy: 0.8371
# Epoch 125/500
# 1000/1000 [==============================] - 1s 676us/step - loss: 0.3991 - accuracy: 0.8357
# Epoch 126/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.3993 - accuracy: 0.8363
# Epoch 127/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3994 - accuracy: 0.8344
# Epoch 128/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3991 - accuracy: 0.8360
# Epoch 129/500
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.3994 - accuracy: 0.8360
# Epoch 130/500
# 1000/1000 [==============================] - 1s 640us/step - loss: 0.3992 - accuracy: 0.8360
# Epoch 131/500
# 1000/1000 [==============================] - 1s 652us/step - loss: 0.3991 - accuracy: 0.8357
# Epoch 132/500
# 1000/1000 [==============================] - 1s 644us/step - loss: 0.3991 - accuracy: 0.8349
# Epoch 133/500
# 1000/1000 [==============================] - 1s 561us/step - loss: 0.3994 - accuracy: 0.8360
# Epoch 134/500
# 1000/1000 [==============================] - 1s 664us/step - loss: 0.3992 - accuracy: 0.8347
# Epoch 135/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.3993 - accuracy: 0.8356
# Epoch 136/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3993 - accuracy: 0.8356
# Epoch 137/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.3997 - accuracy: 0.8346
# Epoch 138/500
# 1000/1000 [==============================] - 1s 651us/step - loss: 0.3993 - accuracy: 0.8357
# Epoch 139/500
# 1000/1000 [==============================] - 1s 635us/step - loss: 0.3994 - accuracy: 0.8364
# Epoch 140/500
# 1000/1000 [==============================] - 1s 651us/step - loss: 0.3988 - accuracy: 0.8363
# Epoch 141/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3996 - accuracy: 0.8366
# Epoch 142/500
# 1000/1000 [==============================] - 1s 693us/step - loss: 0.3982 - accuracy: 0.8359
# Epoch 143/500
# 1000/1000 [==============================] - 1s 687us/step - loss: 0.3996 - accuracy: 0.8347
# Epoch 144/500
# 1000/1000 [==============================] - 1s 708us/step - loss: 0.3990 - accuracy: 0.8356
# Epoch 145/500
# 1000/1000 [==============================] - 1s 686us/step - loss: 0.3992 - accuracy: 0.8360
# Epoch 146/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3995 - accuracy: 0.8371
# Epoch 147/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3992 - accuracy: 0.8363
# Epoch 148/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3992 - accuracy: 0.8357
# Epoch 149/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3988 - accuracy: 0.8341
# Epoch 150/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3989 - accuracy: 0.8363
# Epoch 151/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3992 - accuracy: 0.8372
# Epoch 152/500
# 1000/1000 [==============================] - 1s 687us/step - loss: 0.3990 - accuracy: 0.8361
# Epoch 153/500
# 1000/1000 [==============================] - 1s 681us/step - loss: 0.3988 - accuracy: 0.8360
# Epoch 154/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3990 - accuracy: 0.8360
# Epoch 155/500
# 1000/1000 [==============================] - 1s 667us/step - loss: 0.3989 - accuracy: 0.8360
# Epoch 156/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3990 - accuracy: 0.8355
# Epoch 157/500
# 1000/1000 [==============================] - 1s 668us/step - loss: 0.3993 - accuracy: 0.8345
# Epoch 158/500
# 1000/1000 [==============================] - 1s 664us/step - loss: 0.3993 - accuracy: 0.8364
# Epoch 159/500
# 1000/1000 [==============================] - 1s 683us/step - loss: 0.3995 - accuracy: 0.8366
# Epoch 160/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.3991 - accuracy: 0.8349
# Epoch 161/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3990 - accuracy: 0.8357
# Epoch 162/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3991 - accuracy: 0.8357
# Epoch 163/500
# 1000/1000 [==============================] - 1s 681us/step - loss: 0.3988 - accuracy: 0.8374
# Epoch 164/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3991 - accuracy: 0.8356
# Epoch 165/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3991 - accuracy: 0.8354
# Epoch 166/500
# 1000/1000 [==============================] - 1s 669us/step - loss: 0.3992 - accuracy: 0.8349
# Epoch 167/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3990 - accuracy: 0.8355
# Epoch 168/500
# 1000/1000 [==============================] - 1s 689us/step - loss: 0.3987 - accuracy: 0.8363
# Epoch 169/500
# 1000/1000 [==============================] - 1s 697us/step - loss: 0.3991 - accuracy: 0.8351
# Epoch 170/500
# 1000/1000 [==============================] - 1s 653us/step - loss: 0.3992 - accuracy: 0.8357
# Epoch 171/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3993 - accuracy: 0.8346
# Epoch 172/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3991 - accuracy: 0.8350
# Epoch 173/500
# 1000/1000 [==============================] - 1s 664us/step - loss: 0.3988 - accuracy: 0.8364
# Epoch 174/500
# 1000/1000 [==============================] - 1s 675us/step - loss: 0.3993 - accuracy: 0.8354
# Epoch 175/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.3992 - accuracy: 0.8365
# Epoch 176/500
# 1000/1000 [==============================] - 1s 681us/step - loss: 0.3992 - accuracy: 0.8349
# Epoch 177/500
# 1000/1000 [==============================] - 1s 680us/step - loss: 0.3989 - accuracy: 0.8359
# Epoch 178/500
# 1000/1000 [==============================] - 1s 676us/step - loss: 0.3993 - accuracy: 0.8354
# Epoch 179/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3989 - accuracy: 0.8369
# Epoch 180/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.3993 - accuracy: 0.8347
# Epoch 181/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.3990 - accuracy: 0.8365
# Epoch 182/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3995 - accuracy: 0.8360
# Epoch 183/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3991 - accuracy: 0.8351
# Epoch 184/500
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.3988 - accuracy: 0.8360
# Epoch 185/500
# 1000/1000 [==============================] - 1s 660us/step - loss: 0.3992 - accuracy: 0.8361
# Epoch 186/500
# 1000/1000 [==============================] - 1s 671us/step - loss: 0.3991 - accuracy: 0.8367
# Epoch 187/500
# 1000/1000 [==============================] - 1s 681us/step - loss: 0.3987 - accuracy: 0.8365
# Epoch 188/500
# 1000/1000 [==============================] - 1s 683us/step - loss: 0.3989 - accuracy: 0.8360
# Epoch 189/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3996 - accuracy: 0.8365
# Epoch 190/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3986 - accuracy: 0.8369
# Epoch 191/500
# 1000/1000 [==============================] - 1s 687us/step - loss: 0.3993 - accuracy: 0.8359
# Epoch 192/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3986 - accuracy: 0.8344
# Epoch 193/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3988 - accuracy: 0.8355
# Epoch 194/500
# 1000/1000 [==============================] - 1s 661us/step - loss: 0.3988 - accuracy: 0.8374
# Epoch 195/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3990 - accuracy: 0.8363
# Epoch 196/500
# 1000/1000 [==============================] - 1s 648us/step - loss: 0.3988 - accuracy: 0.8365
# Epoch 197/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3992 - accuracy: 0.8357
# Epoch 198/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3988 - accuracy: 0.8359
# Epoch 199/500
# 1000/1000 [==============================] - 1s 667us/step - loss: 0.3991 - accuracy: 0.8371
# Epoch 200/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3991 - accuracy: 0.8364
# Epoch 201/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3991 - accuracy: 0.8369
# Epoch 202/500
# 1000/1000 [==============================] - 1s 702us/step - loss: 0.3988 - accuracy: 0.8335
# Epoch 203/500
# 1000/1000 [==============================] - 1s 663us/step - loss: 0.3990 - accuracy: 0.8372
# Epoch 204/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3987 - accuracy: 0.8351
# Epoch 205/500
# 1000/1000 [==============================] - 1s 662us/step - loss: 0.3988 - accuracy: 0.8360
# Epoch 206/500
# 1000/1000 [==============================] - 1s 656us/step - loss: 0.3990 - accuracy: 0.8361
# Epoch 207/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.3989 - accuracy: 0.8355
# Epoch 208/500
# 1000/1000 [==============================] - 1s 664us/step - loss: 0.3990 - accuracy: 0.8371
# Epoch 209/500
# 1000/1000 [==============================] - 1s 652us/step - loss: 0.3992 - accuracy: 0.8366
# Epoch 210/500
# 1000/1000 [==============================] - 1s 698us/step - loss: 0.3991 - accuracy: 0.8351
# Epoch 211/500
# 1000/1000 [==============================] - 1s 702us/step - loss: 0.3992 - accuracy: 0.8351
# Epoch 212/500
# 1000/1000 [==============================] - 1s 666us/step - loss: 0.3989 - accuracy: 0.8359
# Epoch 213/500
# 1000/1000 [==============================] - 1s 675us/step - loss: 0.3987 - accuracy: 0.8381
# Epoch 214/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3987 - accuracy: 0.8350
# Epoch 215/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.3989 - accuracy: 0.8366
# Epoch 216/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3990 - accuracy: 0.8349
# Epoch 217/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3989 - accuracy: 0.8359
# Epoch 218/500
# 1000/1000 [==============================] - 1s 666us/step - loss: 0.3986 - accuracy: 0.8356
# Epoch 219/500
# 1000/1000 [==============================] - 1s 657us/step - loss: 0.3988 - accuracy: 0.8364
# Epoch 220/500
# 1000/1000 [==============================] - 1s 661us/step - loss: 0.3992 - accuracy: 0.8374
# Epoch 221/500
# 1000/1000 [==============================] - 1s 662us/step - loss: 0.3989 - accuracy: 0.8364
# Epoch 222/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3987 - accuracy: 0.83600s - loss: 0.3947 - accuracy:
# Epoch 223/500
# 1000/1000 [==============================] - 1s 669us/step - loss: 0.3990 - accuracy: 0.8365
# Epoch 224/500
# 1000/1000 [==============================] - 1s 675us/step - loss: 0.3991 - accuracy: 0.8354
# Epoch 225/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3990 - accuracy: 0.8356
# Epoch 226/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3988 - accuracy: 0.8359
# Epoch 227/500
# 1000/1000 [==============================] - 1s 653us/step - loss: 0.3987 - accuracy: 0.8363
# Epoch 228/500
# 1000/1000 [==============================] - 1s 676us/step - loss: 0.3988 - accuracy: 0.8346
# Epoch 229/500
# 1000/1000 [==============================] - 1s 665us/step - loss: 0.3988 - accuracy: 0.8365
# Epoch 230/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3992 - accuracy: 0.8371
# Epoch 231/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3987 - accuracy: 0.8366
# Epoch 232/500
# 1000/1000 [==============================] - 1s 676us/step - loss: 0.3987 - accuracy: 0.8342
# Epoch 233/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.3989 - accuracy: 0.8354
# Epoch 234/500
# 1000/1000 [==============================] - 1s 689us/step - loss: 0.3991 - accuracy: 0.8359
# Epoch 235/500
# 1000/1000 [==============================] - 1s 693us/step - loss: 0.3983 - accuracy: 0.8374
# Epoch 236/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3987 - accuracy: 0.8372
# Epoch 237/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3984 - accuracy: 0.8355
# Epoch 238/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3990 - accuracy: 0.8381
# Epoch 239/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.3989 - accuracy: 0.8353
# Epoch 240/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3986 - accuracy: 0.8349
# Epoch 241/500
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.3988 - accuracy: 0.8353
# Epoch 242/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3991 - accuracy: 0.8350
# Epoch 243/500
# 1000/1000 [==============================] - 1s 712us/step - loss: 0.3989 - accuracy: 0.8367
# Epoch 244/500
# 1000/1000 [==============================] - 1s 646us/step - loss: 0.3989 - accuracy: 0.8357
# Epoch 245/500
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.3988 - accuracy: 0.8363
# Epoch 246/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3989 - accuracy: 0.8361
# Epoch 247/500
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.3992 - accuracy: 0.8366
# Epoch 248/500
# 1000/1000 [==============================] - 1s 675us/step - loss: 0.3987 - accuracy: 0.8374
# Epoch 249/500
# 1000/1000 [==============================] - 1s 704us/step - loss: 0.3990 - accuracy: 0.8360
# Epoch 250/500
# 1000/1000 [==============================] - 1s 667us/step - loss: 0.3987 - accuracy: 0.8369
# Epoch 251/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3988 - accuracy: 0.8353
# Epoch 252/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3986 - accuracy: 0.8364
# Epoch 253/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3993 - accuracy: 0.8355
# Epoch 254/500
# 1000/1000 [==============================] - 1s 700us/step - loss: 0.3987 - accuracy: 0.8359
# Epoch 255/500
# 1000/1000 [==============================] - 1s 683us/step - loss: 0.3991 - accuracy: 0.8355
# Epoch 256/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3988 - accuracy: 0.8351
# Epoch 257/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3990 - accuracy: 0.8370
# Epoch 258/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3988 - accuracy: 0.8349
# Epoch 259/500
# 1000/1000 [==============================] - 1s 676us/step - loss: 0.3988 - accuracy: 0.8365
# Epoch 260/500
# 1000/1000 [==============================] - 1s 681us/step - loss: 0.3990 - accuracy: 0.8376
# Epoch 261/500
# 1000/1000 [==============================] - 1s 649us/step - loss: 0.3985 - accuracy: 0.8369
# Epoch 262/500
# 1000/1000 [==============================] - 1s 668us/step - loss: 0.3986 - accuracy: 0.8374
# Epoch 263/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3987 - accuracy: 0.8361
# Epoch 264/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3988 - accuracy: 0.8372
# Epoch 265/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.3989 - accuracy: 0.8347
# Epoch 266/500
# 1000/1000 [==============================] - 1s 696us/step - loss: 0.3992 - accuracy: 0.8363
# Epoch 267/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3986 - accuracy: 0.8339
# Epoch 268/500
# 1000/1000 [==============================] - 1s 666us/step - loss: 0.3992 - accuracy: 0.8356
# Epoch 269/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3992 - accuracy: 0.8370
# Epoch 270/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.3990 - accuracy: 0.8370
# Epoch 271/500
# 1000/1000 [==============================] - 1s 669us/step - loss: 0.3992 - accuracy: 0.8372
# Epoch 272/500
# 1000/1000 [==============================] - 1s 696us/step - loss: 0.3989 - accuracy: 0.8357
# Epoch 273/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.3987 - accuracy: 0.8379
# Epoch 274/500
# 1000/1000 [==============================] - 1s 689us/step - loss: 0.3990 - accuracy: 0.8345
# Epoch 275/500
# 1000/1000 [==============================] - 1s 699us/step - loss: 0.3988 - accuracy: 0.8353
# Epoch 276/500
# 1000/1000 [==============================] - 1s 696us/step - loss: 0.3990 - accuracy: 0.8379
# Epoch 277/500
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.3989 - accuracy: 0.8360
# Epoch 278/500
# 1000/1000 [==============================] - 1s 655us/step - loss: 0.3989 - accuracy: 0.8355
# Epoch 279/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.3989 - accuracy: 0.8361
# Epoch 280/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3987 - accuracy: 0.8363
# Epoch 281/500
# 1000/1000 [==============================] - 1s 696us/step - loss: 0.3988 - accuracy: 0.8356
# Epoch 282/500
# 1000/1000 [==============================] - 1s 683us/step - loss: 0.3991 - accuracy: 0.8363
# Epoch 283/500
# 1000/1000 [==============================] - 1s 696us/step - loss: 0.3990 - accuracy: 0.8361
# Epoch 284/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3988 - accuracy: 0.8353
# Epoch 285/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3986 - accuracy: 0.8374
# Epoch 286/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3984 - accuracy: 0.8359
# Epoch 287/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3990 - accuracy: 0.8360
# Epoch 288/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3987 - accuracy: 0.8360
# Epoch 289/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3992 - accuracy: 0.8350
# Epoch 290/500
# 1000/1000 [==============================] - 1s 680us/step - loss: 0.3986 - accuracy: 0.8375
# Epoch 291/500
# 1000/1000 [==============================] - 1s 667us/step - loss: 0.3988 - accuracy: 0.8347
# Epoch 292/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3990 - accuracy: 0.8357
# Epoch 293/500
# 1000/1000 [==============================] - 1s 695us/step - loss: 0.3990 - accuracy: 0.8375
# Epoch 294/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3993 - accuracy: 0.8344
# Epoch 295/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3985 - accuracy: 0.8364
# Epoch 296/500
# 1000/1000 [==============================] - 1s 721us/step - loss: 0.3992 - accuracy: 0.8353
# Epoch 297/500
# 1000/1000 [==============================] - 1s 681us/step - loss: 0.3986 - accuracy: 0.8359
# Epoch 298/500
# 1000/1000 [==============================] - 1s 681us/step - loss: 0.3986 - accuracy: 0.8341
# Epoch 299/500
# 1000/1000 [==============================] - 1s 687us/step - loss: 0.3988 - accuracy: 0.8357
# Epoch 300/500
# 1000/1000 [==============================] - 1s 686us/step - loss: 0.3989 - accuracy: 0.8353
# Epoch 301/500
# 1000/1000 [==============================] - 1s 686us/step - loss: 0.3984 - accuracy: 0.8372
# Epoch 302/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3986 - accuracy: 0.8364
# Epoch 303/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3982 - accuracy: 0.8361
# Epoch 304/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3992 - accuracy: 0.8364
# Epoch 305/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3989 - accuracy: 0.8350
# Epoch 306/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3988 - accuracy: 0.8364
# Epoch 307/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3984 - accuracy: 0.8364
# Epoch 308/500
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.3991 - accuracy: 0.8357
# Epoch 309/500
# 1000/1000 [==============================] - 1s 675us/step - loss: 0.3988 - accuracy: 0.8353
# Epoch 310/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.3988 - accuracy: 0.8374
# Epoch 311/500
# 1000/1000 [==============================] - 1s 698us/step - loss: 0.3987 - accuracy: 0.8365
# Epoch 312/500
# 1000/1000 [==============================] - 1s 695us/step - loss: 0.3988 - accuracy: 0.8360
# Epoch 313/500
# 1000/1000 [==============================] - 1s 686us/step - loss: 0.3985 - accuracy: 0.8349
# Epoch 314/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3991 - accuracy: 0.8355
# Epoch 315/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3988 - accuracy: 0.8355
# Epoch 316/500
# 1000/1000 [==============================] - 1s 710us/step - loss: 0.3986 - accuracy: 0.8366
# Epoch 317/500
# 1000/1000 [==============================] - 1s 689us/step - loss: 0.3984 - accuracy: 0.8359
# Epoch 318/500
# 1000/1000 [==============================] - 1s 635us/step - loss: 0.3984 - accuracy: 0.8372
# Epoch 319/500
# 1000/1000 [==============================] - 1s 669us/step - loss: 0.3994 - accuracy: 0.8359
# Epoch 320/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3988 - accuracy: 0.8363
# Epoch 321/500
# 1000/1000 [==============================] - 1s 652us/step - loss: 0.3988 - accuracy: 0.8369
# Epoch 322/500
# 1000/1000 [==============================] - 1s 675us/step - loss: 0.3989 - accuracy: 0.8361
# Epoch 323/500
# 1000/1000 [==============================] - 1s 696us/step - loss: 0.3986 - accuracy: 0.8357
# Epoch 324/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3986 - accuracy: 0.8345
# Epoch 325/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3984 - accuracy: 0.8355
# Epoch 326/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3993 - accuracy: 0.8360
# Epoch 327/500
# 1000/1000 [==============================] - 1s 681us/step - loss: 0.3981 - accuracy: 0.8374
# Epoch 328/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3990 - accuracy: 0.8355
# Epoch 329/500
# 1000/1000 [==============================] - 1s 695us/step - loss: 0.3989 - accuracy: 0.8345
# Epoch 330/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3983 - accuracy: 0.8361
# Epoch 331/500
# 1000/1000 [==============================] - 1s 667us/step - loss: 0.3987 - accuracy: 0.8351
# Epoch 332/500
# 1000/1000 [==============================] - 1s 687us/step - loss: 0.3987 - accuracy: 0.8355
# Epoch 333/500
# 1000/1000 [==============================] - 1s 706us/step - loss: 0.3992 - accuracy: 0.8369
# Epoch 334/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3979 - accuracy: 0.8355
# Epoch 335/500
# 1000/1000 [==============================] - 1s 669us/step - loss: 0.3981 - accuracy: 0.8353
# Epoch 336/500
# 1000/1000 [==============================] - 1s 668us/step - loss: 0.3993 - accuracy: 0.8356
# Epoch 337/500
# 1000/1000 [==============================] - 1s 694us/step - loss: 0.3993 - accuracy: 0.8351
# Epoch 338/500
# 1000/1000 [==============================] - 1s 675us/step - loss: 0.3989 - accuracy: 0.8347
# Epoch 339/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3988 - accuracy: 0.8346
# Epoch 340/500
# 1000/1000 [==============================] - 1s 693us/step - loss: 0.3987 - accuracy: 0.8350
# Epoch 341/500
# 1000/1000 [==============================] - 1s 680us/step - loss: 0.3988 - accuracy: 0.8356
# Epoch 342/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3986 - accuracy: 0.83670s - loss: 0.3978 - accuracy:
# Epoch 343/500
# 1000/1000 [==============================] - 1s 680us/step - loss: 0.3988 - accuracy: 0.8369
# Epoch 344/500
# 1000/1000 [==============================] - 1s 668us/step - loss: 0.3989 - accuracy: 0.8360
# Epoch 345/500
# 1000/1000 [==============================] - 1s 680us/step - loss: 0.3985 - accuracy: 0.8380
# Epoch 346/500
# 1000/1000 [==============================] - 1s 680us/step - loss: 0.3989 - accuracy: 0.8365
# Epoch 347/500
# 1000/1000 [==============================] - 1s 664us/step - loss: 0.3987 - accuracy: 0.8359
# Epoch 348/500
# 1000/1000 [==============================] - 1s 666us/step - loss: 0.3987 - accuracy: 0.8374
# Epoch 349/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.3983 - accuracy: 0.8366
# Epoch 350/500
# 1000/1000 [==============================] - 1s 699us/step - loss: 0.3983 - accuracy: 0.8372
# Epoch 351/500
# 1000/1000 [==============================] - 1s 680us/step - loss: 0.3989 - accuracy: 0.8351
# Epoch 352/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.3986 - accuracy: 0.8347
# Epoch 353/500
# 1000/1000 [==============================] - 1s 698us/step - loss: 0.3991 - accuracy: 0.8372
# Epoch 354/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3987 - accuracy: 0.8375
# Epoch 355/500
# 1000/1000 [==============================] - 1s 534us/step - loss: 0.3985 - accuracy: 0.8364
# Epoch 356/500
# 1000/1000 [==============================] - 1s 662us/step - loss: 0.3985 - accuracy: 0.8356
# Epoch 357/500
# 1000/1000 [==============================] - 1s 680us/step - loss: 0.3984 - accuracy: 0.8357
# Epoch 358/500
# 1000/1000 [==============================] - 1s 700us/step - loss: 0.3987 - accuracy: 0.8366
# Epoch 359/500
# 1000/1000 [==============================] - 1s 689us/step - loss: 0.3986 - accuracy: 0.8372
# Epoch 360/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.3986 - accuracy: 0.8366
# Epoch 361/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3986 - accuracy: 0.8365
# Epoch 362/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3987 - accuracy: 0.8361
# Epoch 363/500
# 1000/1000 [==============================] - 1s 667us/step - loss: 0.3982 - accuracy: 0.8347
# Epoch 364/500
# 1000/1000 [==============================] - 1s 682us/step - loss: 0.3987 - accuracy: 0.8367
# Epoch 365/500
# 1000/1000 [==============================] - 1s 698us/step - loss: 0.3990 - accuracy: 0.8376
# Epoch 366/500
# 1000/1000 [==============================] - 1s 711us/step - loss: 0.3986 - accuracy: 0.8357
# Epoch 367/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3989 - accuracy: 0.8356
# Epoch 368/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3986 - accuracy: 0.8371
# Epoch 369/500
# 1000/1000 [==============================] - 1s 714us/step - loss: 0.3989 - accuracy: 0.8372
# Epoch 370/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3990 - accuracy: 0.8349
# Epoch 371/500
# 1000/1000 [==============================] - 1s 717us/step - loss: 0.3986 - accuracy: 0.8361
# Epoch 372/500
# 1000/1000 [==============================] - 1s 694us/step - loss: 0.3988 - accuracy: 0.8374
# Epoch 373/500
# 1000/1000 [==============================] - 1s 664us/step - loss: 0.3982 - accuracy: 0.8354
# Epoch 374/500
# 1000/1000 [==============================] - 1s 704us/step - loss: 0.3989 - accuracy: 0.8364
# Epoch 375/500
# 1000/1000 [==============================] - 1s 689us/step - loss: 0.3987 - accuracy: 0.8367
# Epoch 376/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3988 - accuracy: 0.8375
# Epoch 377/500
# 1000/1000 [==============================] - 1s 707us/step - loss: 0.3989 - accuracy: 0.8372
# Epoch 378/500
# 1000/1000 [==============================] - 1s 696us/step - loss: 0.3989 - accuracy: 0.8356
# Epoch 379/500
# 1000/1000 [==============================] - 1s 697us/step - loss: 0.3987 - accuracy: 0.8367
# Epoch 380/500
# 1000/1000 [==============================] - 1s 702us/step - loss: 0.3986 - accuracy: 0.8360
# Epoch 381/500
# 1000/1000 [==============================] - 1s 689us/step - loss: 0.3988 - accuracy: 0.8360
# Epoch 382/500
# 1000/1000 [==============================] - 1s 689us/step - loss: 0.3988 - accuracy: 0.8349
# Epoch 383/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.3987 - accuracy: 0.8372
# Epoch 384/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3980 - accuracy: 0.8361
# Epoch 385/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3993 - accuracy: 0.8364
# Epoch 386/500
# 1000/1000 [==============================] - 1s 686us/step - loss: 0.3984 - accuracy: 0.8355
# Epoch 387/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3985 - accuracy: 0.8360
# Epoch 388/500
# 1000/1000 [==============================] - 1s 706us/step - loss: 0.3991 - accuracy: 0.8364
# Epoch 389/500
# 1000/1000 [==============================] - 1s 681us/step - loss: 0.3985 - accuracy: 0.8344
# Epoch 390/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3988 - accuracy: 0.8361
# Epoch 391/500
# 1000/1000 [==============================] - 1s 697us/step - loss: 0.3989 - accuracy: 0.8350
# Epoch 392/500
# 1000/1000 [==============================] - 1s 703us/step - loss: 0.3987 - accuracy: 0.8369
# Epoch 393/500
# 1000/1000 [==============================] - 1s 701us/step - loss: 0.3986 - accuracy: 0.8354
# Epoch 394/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3988 - accuracy: 0.8374
# Epoch 395/500
# 1000/1000 [==============================] - 1s 651us/step - loss: 0.3985 - accuracy: 0.8361
# Epoch 396/500
# 1000/1000 [==============================] - 1s 583us/step - loss: 0.3980 - accuracy: 0.8357
# Epoch 397/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.3989 - accuracy: 0.8370
# Epoch 398/500
# 1000/1000 [==============================] - 1s 626us/step - loss: 0.3983 - accuracy: 0.8371
# Epoch 399/500
# 1000/1000 [==============================] - 1s 622us/step - loss: 0.3986 - accuracy: 0.8364
# Epoch 400/500
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.3987 - accuracy: 0.8370
# Epoch 401/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.3982 - accuracy: 0.8357
# Epoch 402/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.3987 - accuracy: 0.8357
# Epoch 403/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3987 - accuracy: 0.8360
# Epoch 404/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3990 - accuracy: 0.8370
# Epoch 405/500
# 1000/1000 [==============================] - 1s 707us/step - loss: 0.3988 - accuracy: 0.8361
# Epoch 406/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3985 - accuracy: 0.8376
# Epoch 407/500
# 1000/1000 [==============================] - 1s 704us/step - loss: 0.3990 - accuracy: 0.8359
# Epoch 408/500
# 1000/1000 [==============================] - 1s 680us/step - loss: 0.3983 - accuracy: 0.8367
# Epoch 409/500
# 1000/1000 [==============================] - 1s 695us/step - loss: 0.3989 - accuracy: 0.8363
# Epoch 410/500
# 1000/1000 [==============================] - 1s 641us/step - loss: 0.3989 - accuracy: 0.8369
# Epoch 411/500
# 1000/1000 [==============================] - 1s 592us/step - loss: 0.3987 - accuracy: 0.8350
# Epoch 412/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3984 - accuracy: 0.8354
# Epoch 413/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3986 - accuracy: 0.8360
# Epoch 414/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3985 - accuracy: 0.8372
# Epoch 415/500
# 1000/1000 [==============================] - 1s 701us/step - loss: 0.3987 - accuracy: 0.8351
# Epoch 416/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3984 - accuracy: 0.8355
# Epoch 417/500
# 1000/1000 [==============================] - 1s 689us/step - loss: 0.3982 - accuracy: 0.8361
# Epoch 418/500
# 1000/1000 [==============================] - 1s 670us/step - loss: 0.3985 - accuracy: 0.8367
# Epoch 419/500
# 1000/1000 [==============================] - 1s 699us/step - loss: 0.3987 - accuracy: 0.8365
# Epoch 420/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3990 - accuracy: 0.8355
# Epoch 421/500
# 1000/1000 [==============================] - 1s 693us/step - loss: 0.3992 - accuracy: 0.8366
# Epoch 422/500
# 1000/1000 [==============================] - 1s 669us/step - loss: 0.3988 - accuracy: 0.8351
# Epoch 423/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3989 - accuracy: 0.8357
# Epoch 424/500
# 1000/1000 [==============================] - 1s 693us/step - loss: 0.3988 - accuracy: 0.8349
# Epoch 425/500
# 1000/1000 [==============================] - 1s 696us/step - loss: 0.3987 - accuracy: 0.8354
# Epoch 426/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3986 - accuracy: 0.8355
# Epoch 427/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3982 - accuracy: 0.8369
# Epoch 428/500
# 1000/1000 [==============================] - 1s 715us/step - loss: 0.3988 - accuracy: 0.8356
# Epoch 429/500
# 1000/1000 [==============================] - 1s 678us/step - loss: 0.3991 - accuracy: 0.8371
# Epoch 430/500
# 1000/1000 [==============================] - 1s 693us/step - loss: 0.3984 - accuracy: 0.8369
# Epoch 431/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3983 - accuracy: 0.8350
# Epoch 432/500
# 1000/1000 [==============================] - 1s 665us/step - loss: 0.3983 - accuracy: 0.8361
# Epoch 433/500
# 1000/1000 [==============================] - 1s 671us/step - loss: 0.3989 - accuracy: 0.8363
# Epoch 434/500
# 1000/1000 [==============================] - 1s 671us/step - loss: 0.3985 - accuracy: 0.8360
# Epoch 435/500
# 1000/1000 [==============================] - 1s 666us/step - loss: 0.3988 - accuracy: 0.8340
# Epoch 436/500
# 1000/1000 [==============================] - 1s 652us/step - loss: 0.3988 - accuracy: 0.8367
# Epoch 437/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3982 - accuracy: 0.8372
# Epoch 438/500
# 1000/1000 [==============================] - 1s 597us/step - loss: 0.3987 - accuracy: 0.8357
# Epoch 439/500
# 1000/1000 [==============================] - 1s 628us/step - loss: 0.3989 - accuracy: 0.8376
# Epoch 440/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3988 - accuracy: 0.8365
# Epoch 441/500
# 1000/1000 [==============================] - 1s 679us/step - loss: 0.3989 - accuracy: 0.8342
# Epoch 442/500
# 1000/1000 [==============================] - 1s 547us/step - loss: 0.3986 - accuracy: 0.8361
# Epoch 443/500
# 1000/1000 [==============================] - 1s 617us/step - loss: 0.3988 - accuracy: 0.8355
# Epoch 444/500
# 1000/1000 [==============================] - 1s 640us/step - loss: 0.3984 - accuracy: 0.8366
# Epoch 445/500
# 1000/1000 [==============================] - 1s 618us/step - loss: 0.3986 - accuracy: 0.8369
# Epoch 446/500
# 1000/1000 [==============================] - 1s 650us/step - loss: 0.3986 - accuracy: 0.8374
# Epoch 447/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.3985 - accuracy: 0.8364
# Epoch 448/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3985 - accuracy: 0.8353
# Epoch 449/500
# 1000/1000 [==============================] - 1s 683us/step - loss: 0.3987 - accuracy: 0.8359
# Epoch 450/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3989 - accuracy: 0.8349
# Epoch 451/500
# 1000/1000 [==============================] - 1s 698us/step - loss: 0.3985 - accuracy: 0.8361
# Epoch 452/500
# 1000/1000 [==============================] - 1s 660us/step - loss: 0.3985 - accuracy: 0.8357
# Epoch 453/500
# 1000/1000 [==============================] - 1s 657us/step - loss: 0.3990 - accuracy: 0.8382
# Epoch 454/500
# 1000/1000 [==============================] - 1s 708us/step - loss: 0.3986 - accuracy: 0.8359
# Epoch 455/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3984 - accuracy: 0.8359
# Epoch 456/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3988 - accuracy: 0.8349
# Epoch 457/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.3986 - accuracy: 0.8360
# Epoch 458/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3987 - accuracy: 0.8349
# Epoch 459/500
# 1000/1000 [==============================] - 1s 651us/step - loss: 0.3981 - accuracy: 0.8349
# Epoch 460/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3984 - accuracy: 0.8367
# Epoch 461/500
# 1000/1000 [==============================] - 1s 673us/step - loss: 0.3981 - accuracy: 0.8371
# Epoch 462/500
# 1000/1000 [==============================] - 1s 687us/step - loss: 0.3990 - accuracy: 0.8350
# Epoch 463/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3987 - accuracy: 0.8356
# Epoch 464/500
# 1000/1000 [==============================] - 1s 696us/step - loss: 0.3987 - accuracy: 0.8356
# Epoch 465/500
# 1000/1000 [==============================] - 1s 667us/step - loss: 0.3983 - accuracy: 0.8374
# Epoch 466/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.3986 - accuracy: 0.8349
# Epoch 467/500
# 1000/1000 [==============================] - 1s 686us/step - loss: 0.3986 - accuracy: 0.8356
# Epoch 468/500
# 1000/1000 [==============================] - 1s 687us/step - loss: 0.3986 - accuracy: 0.8369
# Epoch 469/500
# 1000/1000 [==============================] - 1s 689us/step - loss: 0.3987 - accuracy: 0.8366
# Epoch 470/500
# 1000/1000 [==============================] - 1s 692us/step - loss: 0.3988 - accuracy: 0.8360
# Epoch 471/500
# 1000/1000 [==============================] - 1s 695us/step - loss: 0.3986 - accuracy: 0.8356
# Epoch 472/500
# 1000/1000 [==============================] - 1s 691us/step - loss: 0.3987 - accuracy: 0.8354
# Epoch 473/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3985 - accuracy: 0.8364
# Epoch 474/500
# 1000/1000 [==============================] - 1s 671us/step - loss: 0.3987 - accuracy: 0.8365
# Epoch 475/500
# 1000/1000 [==============================] - 1s 672us/step - loss: 0.3987 - accuracy: 0.8353
# Epoch 476/500
# 1000/1000 [==============================] - 1s 663us/step - loss: 0.3990 - accuracy: 0.8356
# Epoch 477/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3986 - accuracy: 0.8361
# Epoch 478/500
# 1000/1000 [==============================] - 1s 704us/step - loss: 0.3988 - accuracy: 0.8366
# Epoch 479/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.3990 - accuracy: 0.8353
# Epoch 480/500
# 1000/1000 [==============================] - 1s 665us/step - loss: 0.3988 - accuracy: 0.8351
# Epoch 481/500
# 1000/1000 [==============================] - 1s 685us/step - loss: 0.3982 - accuracy: 0.8364
# Epoch 482/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3987 - accuracy: 0.8371
# Epoch 483/500
# 1000/1000 [==============================] - 1s 688us/step - loss: 0.3984 - accuracy: 0.8357
# Epoch 484/500
# 1000/1000 [==============================] - 1s 698us/step - loss: 0.3985 - accuracy: 0.8367
# Epoch 485/500
# 1000/1000 [==============================] - 1s 675us/step - loss: 0.3983 - accuracy: 0.8375
# Epoch 486/500
# 1000/1000 [==============================] - 1s 705us/step - loss: 0.3986 - accuracy: 0.8359
# Epoch 487/500
# 1000/1000 [==============================] - 1s 674us/step - loss: 0.3984 - accuracy: 0.8357
# Epoch 488/500
# 1000/1000 [==============================] - 1s 699us/step - loss: 0.3988 - accuracy: 0.8375
# Epoch 489/500
# 1000/1000 [==============================] - 1s 705us/step - loss: 0.3986 - accuracy: 0.8370
# Epoch 490/500
# 1000/1000 [==============================] - 1s 694us/step - loss: 0.3984 - accuracy: 0.8376
# Epoch 491/500
# 1000/1000 [==============================] - 1s 666us/step - loss: 0.3985 - accuracy: 0.8354
# Epoch 492/500
# 1000/1000 [==============================] - 1s 677us/step - loss: 0.3983 - accuracy: 0.8363
# Epoch 493/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3989 - accuracy: 0.8378
# Epoch 494/500
# 1000/1000 [==============================] - 1s 713us/step - loss: 0.3984 - accuracy: 0.8354
# Epoch 495/500
# 1000/1000 [==============================] - 1s 694us/step - loss: 0.3989 - accuracy: 0.8364
# Epoch 496/500
# 1000/1000 [==============================] - 1s 680us/step - loss: 0.3990 - accuracy: 0.8357
# Epoch 497/500
# 1000/1000 [==============================] - 1s 664us/step - loss: 0.3984 - accuracy: 0.8360
# Epoch 498/500
# 1000/1000 [==============================] - 1s 684us/step - loss: 0.3987 - accuracy: 0.8364
# Epoch 499/500
# 1000/1000 [==============================] - 1s 716us/step - loss: 0.3987 - accuracy: 0.8363
# Epoch 500/500
# 1000/1000 [==============================] - 1s 690us/step - loss: 0.3988 - accuracy: 0.8351

# %%
grid_search = grid_search.fit(X_train, y_train)

# %%
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_

# %% [markdown]
# # Conclusion
#
# In this program,  we shown a simple example how to build an ANN.  The objective of build a good regression model was achieved, the model presents an accuracy of $85.9 \%$. Artificial Neuron Network has a has a wide applicability, we might also to build regression models. Whit the classification model, we are free to apply in many problems, for example image recognition. Methods like this might be helpful tool in decision-make about client polices.
